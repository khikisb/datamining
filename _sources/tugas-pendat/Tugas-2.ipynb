# %% [markdown]
# # Tugas 2 ( Diskritasi )
# # Penambangan Data
# Nama :Okhi Sahrul Barkah
#
# NIM  : 210411100112

# %% [markdown]
# Link Goggle Colab for play this code :
#
# https://colab.research.google.com/drive/1XWaNh9vgcOfUy75ikWtZh_G7ZpLlJp4c

# %% [markdown]
# # Tugas Melakukan diskritisasi
#
# Carilah data yang bertipe numerik ( data klassifikasi)
#
# 1. Lakukan proses diskritisasi dengan equal width dan equal frequency
#
# 2. Lakukan proses diskritisasi  dengan basis entropy
#
# yang diupload adalah link github ( web statis dari jupyter book)

# %%
import pandas as pd
data = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Pandas
#
# adalah modul yang digunakan untuk data analisis dan struktur data. Salah satu tools dari pandas adalah cut dan qcut.
#
# **cut** menggunakan equal-width
# # Syntax cut
# pd.cut(series, interval, right=True, label)
#
# ,
#
# sedangkan, **qcut** menggunakan equal-frequency.
#
# # Syntax qcut
# pd.qcut(series, interval, label)

# %% [markdown]
# # Equal-width Intervals
#
# Equal-width intervals adalah discretization yang membagi data numerik menjadi beberapa kelompok dengan lebar kelompok yang kurang lebih sama besar.

# %%
# CONSTAN SERIES

SEPAL_LENGTH = data["sepal.length"]
SEPAL_WIDTH= data["sepal.width"]
PETAL_LENGTH= data["petal.length"]
PETAL_WIDTH= data["petal.width"]

# %% [markdown]
# # Sepal Width
# Equal Width Intervals lebar kelopak bunga Iris
#
# Dikelompokkan menjadi 3 kategori yaitu
#
#
# *   Kategori sempit
# *   Kategori lebar
# *   kategoti sangat lebar

# %%
# equal-width intervals

labels = ["Sempit", "Lebar", "Sangat Lebar"]
binning = len(labels)

sepal_width_ew = pd.cut(SEPAL_WIDTH, binning, True, labels)
labelled_sepal_width_binning = sepal_width_ew.value_counts()
interval_sepal_width_binning = pd.cut(SEPAL_WIDTH, binning, True).value_counts()

# %%
# equal-width intervals binning with label
# labelled_sepal_width_binning

data_sepal_width_ew = pd.concat((SEPAL_WIDTH, sepal_width_ew), axis=1)

# %%
data_sepal_width_ew.columns = ["sepal.width", "attribute"]

# %%
data_sepal_width_ew
# Out:
#      sepal.width attribute
# 0            3.5     Lebar
# 1            3.0     Lebar
# 2            3.2     Lebar
# 3            3.1     Lebar
# 4            3.6     Lebar
# ..           ...       ...
# 145          3.0     Lebar
# 146          2.5    Sempit
# 147          3.0     Lebar
# 148          3.4     Lebar
# 149          3.0     Lebar
#
# [150 rows x 2 columns]

# %%
# Equal-width interval Sepal.width
labelled_sepal_width_binning
# Out:
# Lebar           88
# Sempit          47
# Sangat Lebar    15
# Name: sepal.width, dtype: int64

# %%
# Equal-width intervals without label
interval_sepal_width_binning
# Out:
# (2.8, 3.6]      88
# (1.998, 2.8]    47
# (3.6, 4.4]      15
# Name: sepal.width, dtype: int64

# %% [markdown]
# # Petal Width
#
# Equal Width Intervals lebar mahkota bunga Iris
#
# Dikelompokkan menjadi 3 kategori yaitu
#
# *   Kategori sempit
# *   Kategori lebar
# *   kategoti sangat lebar

# %%
# equal-width intervals

labels = ["Sempit", "Lebar", "Sangat Lebar"]
binning = len(labels)

petal_width_ew = pd.cut(PETAL_WIDTH, binning, True, labels)
labelled_petal_width_binning = petal_width_ew.value_counts()
interval_petal_width_binning = pd.cut(PETAL_WIDTH, binning, True).value_counts()

# %%
# petal-width and petal category

data_petal_width_ew = pd.concat((PETAL_WIDTH, petal_width_ew), axis=1)

# %%
data_petal_width_ew.columns = ["petal.width", "attribute"]

# %%
data_petal_width_ew
# Out:
#      petal.width     attribute
# 0            0.2        Sempit
# 1            0.2        Sempit
# 2            0.2        Sempit
# 3            0.2        Sempit
# 4            0.2        Sempit
# ..           ...           ...
# 145          2.3  Sangat Lebar
# 146          1.9  Sangat Lebar
# 147          2.0  Sangat Lebar
# 148          2.3  Sangat Lebar
# 149          1.8  Sangat Lebar
#
# [150 rows x 2 columns]

# %%
# equal-width intervals with label
labelled_petal_width_binning
# Out:
# Lebar           54
# Sempit          50
# Sangat Lebar    46
# Name: petal.width, dtype: int64

# %%
# equal-width intervals without label
interval_petal_width_binning
# Out:
# (0.9, 1.7]       54
# (0.0976, 0.9]    50
# (1.7, 2.5]       46
# Name: petal.width, dtype: int64

# %% [markdown]
# # Sepal Length
#
# Equal Width Intervals panjang kelopak bunga Iris
#
# Dikelompokkan menjadi 3 kategori yaitu
#
# *   Kategori sempit
# *   Kategori lebar
# *   kategoti sangat lebar

# %%
# equal-width intervals

labels = ["Sempit", "Lebar", "Sangat Lebar"]
binning = len(labels)

sepal_length_ew = pd.cut(SEPAL_LENGTH, binning, True, labels)
labelled_sepal_length_binning = sepal_length_ew.value_counts()
interval_sepal_length_binning = pd.cut(SEPAL_LENGTH, binning, True).value_counts()

# %%
# sepal-lenght and sepal category

data_sepal_lenght_ew = pd.concat((SEPAL_LENGTH, sepal_length_ew), axis=1)

# %%
data_sepal_lenght_ew.columns = ["sepal.lenght", "attribute"]

# %%
data_sepal_lenght_ew
# Out:
#      sepal.lenght attribute
# 0             5.1    Sempit
# 1             4.9    Sempit
# 2             4.7    Sempit
# 3             4.6    Sempit
# 4             5.0    Sempit
# ..            ...       ...
# 145           6.7     Lebar
# 146           6.3     Lebar
# 147           6.5     Lebar
# 148           6.2     Lebar
# 149           5.9     Lebar
#
# [150 rows x 2 columns]

# %%
# equal-width intervals with label
labelled_sepal_length_binning
# Out:
# Lebar           71
# Sempit          59
# Sangat Lebar    20
# Name: sepal.length, dtype: int64

# %%
# equal-width intervals without label

interval_sepal_length_binning
# Out:
# (5.5, 6.7]      71
# (4.296, 5.5]    59
# (6.7, 7.9]      20
# Name: sepal.length, dtype: int64

# %% [markdown]
# # Petal Length
#
# Equal Width Intervals panjang mahkota bunga Iris
#
# Dikelompokkan menjadi 3 kategori yaitu
#
# *   Kategori sempit
# *   Kategori lebar
# *   kategoti sangat lebar

# %%
# equal-width intervals

labels = ["Sempit", "Lebar", "Sangat Lebar"]
binning = len(labels)

petal_length_ew = pd.cut(PETAL_LENGTH, binning, True, labels)
labelled_petal_length_binning = petal_length_ew.value_counts()
interval_petal_length_binning = pd.cut(PETAL_LENGTH, binning, True).value_counts()

# %%
# Petal-width and Petal category

data_petal_length_ew = pd.concat((PETAL_LENGTH, petal_length_ew), axis=1)

# %%
data_petal_length_ew.columns = ["petal.lenght", "attribute"]

# %%
data_petal_length_ew
# Out:
#      petal.lenght     attribute
# 0             1.4        Sempit
# 1             1.4        Sempit
# 2             1.3        Sempit
# 3             1.5        Sempit
# 4             1.4        Sempit
# ..            ...           ...
# 145           5.2  Sangat Lebar
# 146           5.0  Sangat Lebar
# 147           5.2  Sangat Lebar
# 148           5.4  Sangat Lebar
# 149           5.1  Sangat Lebar
#
# [150 rows x 2 columns]

# %%
# equal-width intervals binning with label

labelled_petal_length_binning
# Out:
# Lebar           54
# Sempit          50
# Sangat Lebar    46
# Name: petal.length, dtype: int64

# %%
# equal-width intervals out label

interval_petal_length_binning
# Out:
# (2.967, 4.933]    54
# (0.994, 2.967]    50
# (4.933, 6.9]      46
# Name: petal.length, dtype: int64

# %% [markdown]
# # Equal-frequency Intervals
#
# Equal-frequency intervals adalah discretization yang membagi data numerik menjadi beberapa kelompok dengan jumlah anggota yang kurang lebih sama besar.

# %%
# equal-frequency intervals

labels = ["Sempit", "Lebar", "Sangat Lebar"]
binning = len(labels)

sepal_width_ef = pd.qcut(SEPAL_WIDTH, binning, labels)
labelled_sepal_width_ef = sepal_width_ef.value_counts()
interval_sepal_width_ef = pd.qcut(SEPAL_WIDTH, binning).value_counts()

# %%
# sepal-width and sepal category

data_sepal_width_ef = pd.concat((SEPAL_WIDTH, sepal_width_ef), axis = 1)

# %%
data_sepal_width_ef.columns = ["sepal_width", "attribute"]

# %%
data_sepal_width_ef
# Out:
#      sepal_width     attribute
# 0            3.5  Sangat Lebar
# 1            3.0         Lebar
# 2            3.2         Lebar
# 3            3.1         Lebar
# 4            3.6  Sangat Lebar
# ..           ...           ...
# 145          3.0         Lebar
# 146          2.5        Sempit
# 147          3.0         Lebar
# 148          3.4  Sangat Lebar
# 149          3.0         Lebar
#
# [150 rows x 2 columns]

# %%
# equal-frequency intervals binning with label

labelled_sepal_width_ef
# Out:
# Sempit          57
# Lebar           50
# Sangat Lebar    43
# Name: sepal.width, dtype: int64

# %%
# equal-frequency intervals without label

interval_sepal_width_ef
# Out:
# (1.999, 2.9]    57
# (2.9, 3.2]      50
# (3.2, 4.4]      43
# Name: sepal.width, dtype: int64

# %% [markdown]
# # Petal Width
#
# Equal Frequency Intervals lebar mahkota bunga Iris
#
# Dikelompokkan menjadi 3 kategori yaitu
#
# *   Kategori sempit
# *   Kategori lebar
# *   kategoti sangat lebar

# %%
# equal-frequency intervals

labels = ["Sempit", "Lebar", "Sangat Lebar"]
binning = len(labels)

petal_width_ef = pd.qcut(PETAL_WIDTH, binning, labels)
labelled_petal_width_ef = petal_width_ef.value_counts()
interval_petal_width_ef = pd.qcut(PETAL_WIDTH, binning).value_counts()

# %%
# petal-width and petal category
data_petal_width_ef = pd.concat((PETAL_WIDTH, petal_width_ef), axis = 1)

# %%
data_petal_width_ef.columns = ["petal_width", "attribute"]

# %%
data_petal_width_ef
# Out:
#      petal_width     attribute
# 0            0.2        Sempit
# 1            0.2        Sempit
# 2            0.2        Sempit
# 3            0.2        Sempit
# 4            0.2        Sempit
# ..           ...           ...
# 145          2.3  Sangat Lebar
# 146          1.9  Sangat Lebar
# 147          2.0  Sangat Lebar
# 148          2.3  Sangat Lebar
# 149          1.8  Sangat Lebar
#
# [150 rows x 2 columns]

# %%
# equal-frequency intervals binning with label

labelled_petal_width_ef
# Out:
# Lebar           52
# Sempit          50
# Sangat Lebar    48
# Name: petal.width, dtype: int64

# %%
# equal-frequency intervals without label

interval_petal_width_ef
# Out:
# (0.867, 1.6]      52
# (0.099, 0.867]    50
# (1.6, 2.5]        48
# Name: petal.width, dtype: int64

# %% [markdown]
# # Sepal Length
#
# Equal Frequency Intervals panjang kelopak bunga Iris
#
# Dikelompokkan menjadi 3 kategori yaitu
#
# *   Kategori sempit
# *   Kategori lebar
# *   Kategori sangat lebar

# %%
# equal-frequency intervals

labels = ["Sempit", "Lebar", "Sangat Lebar"]
binning = len(labels)

sepal_length_ef = pd.qcut(SEPAL_LENGTH, binning, labels)
labelled_sepal_length_ef = sepal_length_ef.value_counts()
interval_sepal_length_ef = pd.qcut(SEPAL_LENGTH, binning).value_counts()

# %%
# sepal-length and sepal category

data_sepal_length_ef = pd.concat((SEPAL_LENGTH, sepal_length_ef), axis=1)

# %%
data_sepal_length_ef.columns = ["sepal.lenght", "attribute"]

# %%
data_sepal_length_ef
# Out:
#      sepal.lenght     attribute
# 0             5.1        Sempit
# 1             4.9        Sempit
# 2             4.7        Sempit
# 3             4.6        Sempit
# 4             5.0        Sempit
# ..            ...           ...
# 145           6.7  Sangat Lebar
# 146           6.3         Lebar
# 147           6.5  Sangat Lebar
# 148           6.2         Lebar
# 149           5.9         Lebar
#
# [150 rows x 2 columns]

# %%
# equal-frequency intervals binning with label

labelled_sepal_length_ef
# Out:
# Lebar           56
# Sempit          52
# Sangat Lebar    42
# Name: sepal.length, dtype: int64

# %%
# equal-frequency intervals without label

interval_sepal_length_ef
# Out:
# (5.4, 6.3]                   56
# (4.2989999999999995, 5.4]    52
# (6.3, 7.9]                   42
# Name: sepal.length, dtype: int64

# %% [markdown]
# # Petal Length
#
# Equal Frequency Intervals panjang mahkota bunga Iris
#
# Dikelompokkan menjadi 3 kategori yaitu
#
# *   Kategori sempit
# *   Kategori lebar
# *   Kategori sangat lebar

# %%
# equal-frequency intervals

labels = ["Sempit", "Lebar", "Sangat Lebar"]
binning = len(labels)

petal_length_ef = pd.qcut(PETAL_LENGTH, binning, labels)
labelled_petal_length_ef = petal_length_ef.value_counts()
interval_petal_length_ef = pd.qcut(PETAL_LENGTH, binning).value_counts()

# %%
# petal-length and petal category

data_petal_length_ef = pd.concat((PETAL_LENGTH, petal_length_ef), axis=1)

# %%
data_petal_length_ef.columns = ["petal.length", "attribute"]

# %%
data_petal_length_ef
# Out:
#      petal.length     attribute
# 0             1.4        Sempit
# 1             1.4        Sempit
# 2             1.3        Sempit
# 3             1.5        Sempit
# 4             1.4        Sempit
# ..            ...           ...
# 145           5.2  Sangat Lebar
# 146           5.0  Sangat Lebar
# 147           5.2  Sangat Lebar
# 148           5.4  Sangat Lebar
# 149           5.1  Sangat Lebar
#
# [150 rows x 2 columns]

# %%
# equal-frequency intervals binning with label

labelled_petal_length_ef
# Out:
# Lebar           54
# Sempit          50
# Sangat Lebar    46
# Name: petal.length, dtype: int64

# %%
# equal-frequency intervals wihout label

interval_petal_length_ef
# Out:
# (2.633, 4.9]      54
# (0.999, 2.633]    50
# (4.9, 6.9]        46
# Name: petal.length, dtype: int64

# %% [markdown]
# # Binning Entropy
#
# Ukuran ketidakpastian dari suatu informasi, cara menghitungnya melibatkan atribut / Kelas
#
# Rumus Binning Entropy :
#
# $$
# \begin{align*}
# \displaystyle Entropy(D1) &= \sum_{i=0}^{k} -pi \ log_{2} \ pi \\
# \end{align*}
# $$

# %%
from math import log2
target_data = data_petal_width_ef
target_data
# Out:
#      petal_width     attribute
# 0            0.2        Sempit
# 1            0.2        Sempit
# 2            0.2        Sempit
# 3            0.2        Sempit
# 4            0.2        Sempit
# ..           ...           ...
# 145          2.3  Sangat Lebar
# 146          1.9  Sangat Lebar
# 147          2.0  Sangat Lebar
# 148          2.3  Sangat Lebar
# 149          1.8  Sangat Lebar
#
# [150 rows x 2 columns]

# %%
labels = ["Sempit", "Lebar", "Sangat Lebar"]

# %%
# count every value based the given attribute
def countEveryAttribute(data_column, labels, column, attribute):
    group = data_column.groupby(attribute).count()
    amount_of_every_attribute = []
    for label in labels:
        amount_of_every_attribute.append(group.loc[label, column])
    return amount_of_every_attribute

# %%
# split the given data based on attribute and split value 
def split(split_value, data_column, labels, col, attribute):
    less_group = data_column[data_column[col] < split_value]
    greater_group = data_column[data_column[col] >= split_value]
    
    length_less_group = countEveryAttribute(less_group, labels, col, attribute)
    length_greater_group = countEveryAttribute(greater_group, labels, col, attribute)
    
    return (length_less_group, length_greater_group)

# %% [markdown]
# ### Fungsi menghitung perbedaan *gain* antara entropi inisial dengan entropi nilai pembagi yang diberikan
#
#
# Rumus Information Gain :
#
# ---
# $$Gain(E_{ence}) = (E_{initial}) \ - (E_{ence})$$
# ---

# %%
# count information gain from inisial entropy and new entropy
def count_gain(inisial_entropy, new_entropy):
  return inisial_entropy - new_entropy

# %%
# count entropy
def count_entropy(data_target):
    all_prob = []
    for prob in data_target:
        if (prob/sum(data_target) != 0):
            all_prob.append(prob/sum(data_target) * log2(prob/sum(data_target)))
        else:
            all_prob.append(0)
    return -(sum(all_prob))

# %% [markdown]
# #### Fungsi menghitung Info entropy berdasarkan nilai pembagi atau *split value* yang diberikan
#
#
# ---
#
#
#
# $$ Info_A(D) = \frac{|D_1|}{|D|} Entropy (D_1)\frac{|D_2|}{|D|}+ Entropy (D_2)$$

# %%
# count entropy for given a split value
def info(d, data_target):
    temp = []
    for value in d:
        temp.append((sum(value) / data_target.shape[0]) * count_entropy(value))
    return sum(temp)

# %% [markdown]
# #### Implementasi
#
#
# *   Hitung target *entropy*
# *   Hitung target *entropy* dengan *split value*
# *   Hitung *entropy gain*

# %%
# entropy data target
initial_data_target_entropy = count_entropy(countEveryAttribute(target_data, labels, target_data.columns[0], target_data.columns[1]))

# %%
# count Entropy for the target given a split value, split value = 0.7
entropy_data_target_1 = info(split(0.7, target_data, labels, target_data.columns[0], target_data.columns[1]), target_data)

# %%
# information gain (entropy data target and entropy_data_target_1)
count_gain(initial_data_target_entropy, entropy_data_target_1)
# Out:
# 0.9182958340544896

# %%
# count Entropy for the target given a split value, split value = 0.7
entropy_data_target_2 = info(split(1.4, target_data, labels, target_data.columns[0], target_data.columns[1]), target_data)

# %%
# information gain (entropy data target and entropy_data_target_2)
count_gain(initial_data_target_entropy, entropy_data_target_2)
# Out:
# 0.6536600192724277

# %%
# count Entropy for the target given a split value, split value = 0.7
entropy_data_target_3 = info(split(2.1, target_data, labels, target_data.columns[0], target_data.columns[1]), target_data)

# %%
# information gain (entropy data target and entropy_data_target_3)
count_gain(initial_data_target_entropy, entropy_data_target_3)
# Out:
# 0.2985203537604644
